# %% [markdown]
# #UN Data Analysis

# %% [markdown]
# Analysis on UN Data comparing gdp per capita and internet usage

# %% [markdown]
# Import library packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Formatting

# %%
# %matplotlib inline

# %% [markdown]
# #### Load Data

# %%
pd.read_csv('../data/gdp_percapita.csv')
# Out:
#      Country or Area                                      Year        Value  \
# 0        Afghanistan                                      2018  1734.723214
# 1        Afghanistan                                      2017  1758.465636
# 2        Afghanistan                                      2016  1757.023490
# 3        Afghanistan                                      2015  1766.593077
# 4        Afghanistan                                      2014  1795.735834
# ...              ...                                       ...          ...
# 6726        Zimbabwe                                      1992  2591.007534
# 6727        Zimbabwe                                      1991  2906.272849
# 6728        Zimbabwe                                      1990  2819.549467
# 6729   footnoteSeqID                                  Footnote          NaN
# 6730               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 6726              NaN
# 6727              NaN
# 6728              NaN
# 6729              NaN
# 6730              NaN
#
# [6731 rows x 4 columns]

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv', nrows=6729)

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  1734.723214              NaN
# 1     Afghanistan  2017  1758.465636              NaN
# 2     Afghanistan  2016  1757.023490              NaN
# 3     Afghanistan  2015  1766.593077              NaN
# 4     Afghanistan  2014  1795.735834              NaN
# 5     Afghanistan  2013  1807.762344              NaN

# %%
internet_df2 = pd.read_csv('../data/internet_use.csv', nrows=4495)

# %%
internet_df2.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %%
gdp_df[-10:]
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6719        Zimbabwe  1999  3054.064189              NaN
# 6720        Zimbabwe  1998  3099.076182              NaN
# 6721        Zimbabwe  1997  3036.422224              NaN
# 6722        Zimbabwe  1996  2985.856605              NaN
# 6723        Zimbabwe  1995  2736.486436              NaN
# 6724        Zimbabwe  1994  2768.309953              NaN
# 6725        Zimbabwe  1993  2572.870395              NaN
# 6726        Zimbabwe  1992  2591.007534              NaN
# 6727        Zimbabwe  1991  2906.272849              NaN
# 6728        Zimbabwe  1990  2819.549467              NaN

# %%
internet_df2[-10:]
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %% [markdown]
# Question 10 - Drop the 'value footnotes' data (column) from both datasets. Check that this worked as expected.

# %%
gdp_df = gdp_df.drop('Value Footnotes',1)

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2018  1734.723214
# 1     Afghanistan  2017  1758.465636
# 2     Afghanistan  2016  1757.023490
# 3     Afghanistan  2015  1766.593077
# 4     Afghanistan  2014  1795.735834
# 5     Afghanistan  2013  1807.762344

# %%
internet_df2 = internet_df2.drop('Value Footnotes',1)

# %%
internet_df2.head(6)
# Out:
#   Country or Area  Year     Value
# 0     Afghanistan  2014  6.390000
# 1     Afghanistan  2013  5.900000
# 2     Afghanistan  2012  5.454545
# 3     Afghanistan  2011  5.000000
# 4     Afghanistan  2010  4.000000
# 5     Afghanistan  2009  3.550000

# %%
internet_df2.shape
# Out:
# (4495, 3)

# %%
gdp_df.shape
# Out:
# (6729, 3)

# %% [markdown]
# Question 11 - Change the columns for the GDP Per Capita data frame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.

# %%
gdp_df = gdp_df.rename(columns={'Country or Area':'Country','Value':'GDP_Per_Capita'})

# %% [markdown]
# internet_df2.rename(columns={'Country or Area':'Country','Value':'Internet_Users_Pct'})

# %% [markdown]
# Question 12 - Change the columns for the Internet Users data frame to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’.

# %%
internet_df2 = internet_df2.rename(columns={'Country or Area':'Country','Value':'Internet_Users_Pct'})

# %%
gdp_df.info
# Out:
# <bound method DataFrame.info of           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2018     1734.723214
# 1     Afghanistan  2017     1758.465636
# 2     Afghanistan  2016     1757.023490
# 3     Afghanistan  2015     1766.593077
# 4     Afghanistan  2014     1795.735834
# ...           ...   ...             ...
# 6724     Zimbabwe  1994     2768.309953
# 6725     Zimbabwe  1993     2572.870395
# 6726     Zimbabwe  1992     2591.007534
# 6727     Zimbabwe  1991     2906.272849
# 6728     Zimbabwe  1990     2819.549467
#
# [6729 rows x 3 columns]>

# %%
internet_df2.info
# Out:
# <bound method DataFrame.info of           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]>

# %%
gdp_df.dtypes
# Out:
# Country            object
# Year                int64
# GDP_Per_Capita    float64
# dtype: object

# %%
internet_df2.dtypes
# Out:
# Country                object
# Year                    int64
# Internet_Users_Pct    float64
# dtype: object

# %% [markdown]
# Question 13 - Merge the two DataFrames to one. Merge all rows from each of the two DataFrames. Call the new DataFrame gdp_and_internet_use.

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df2, on=['Country','Year'], how='outer')
gdp_and_internet_use.head()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2018     1734.723214                 NaN
# 1  Afghanistan  2017     1758.465636                 NaN
# 2  Afghanistan  2016     1757.023490                 NaN
# 3  Afghanistan  2015     1766.593077                 NaN
# 4  Afghanistan  2014     1795.735834                6.39

# %% [markdown]
# Question 14 - Look at the first five rows of your new data frame to confirm it merged correctly

# %%
gdp_and_internet_use.head(5)
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2018     1734.723214                 NaN
# 1  Afghanistan  2017     1758.465636                 NaN
# 2  Afghanistan  2016     1757.023490                 NaN
# 3  Afghanistan  2015     1766.593077                 NaN
# 4  Afghanistan  2014     1795.735834                6.39

# %% [markdown]
# Question 15 - Look at the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use.tail(5)
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7700  Virgin Islands (U.S.)  1997             NaN            6.948369
# 7701  Virgin Islands (U.S.)  1996             NaN            4.647186
# 7702  Virgin Islands (U.S.)  1995             NaN            2.801958
# 7703  Virgin Islands (U.S.)  1994             NaN            0.940645
# 7704  Virgin Islands (U.S.)  1990             NaN            0.000000

# %% [markdown]
# Question 16 - Subset the combined data frame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
gdp_and_internet_use_subset = gdp_and_internet_use[gdp_and_internet_use["Year"].isin([2004,2009,2014])]

# %%
gdp_and_internet_use_subset.head(10)
# Out:
#         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4   Afghanistan  2014     1795.735834            6.390000
# 9   Afghanistan  2009     1502.354073            3.550000
# 14  Afghanistan  2004     1025.208245            0.105809
# 21      Albania  2014    10700.993216           60.100000
# 26      Albania  2009     9525.377979           41.200000
# 31      Albania  2004     7001.054082            2.420388
# 50      Algeria  2014    13557.769757           18.090000
# 55      Algeria  2009    12697.690780           11.230000
# 60      Algeria  2004    11845.170512            4.634475
# 79       Angola  2014     6813.052106           21.260000

# %% [markdown]
# Question 17 - Create three new data frames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
df_2004 = gdp_and_internet_use[gdp_and_internet_use["Year"].isin([2004])]

# %%
df_2004.head(6)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 14           Afghanistan  2004     1025.208245            0.105809
# 31               Albania  2004     7001.054082            2.420388
# 60               Algeria  2004    11845.170512            4.634475
# 89                Angola  2004     4604.657044            0.464815
# 118  Antigua and Barbuda  2004    21161.123532           24.266544
# 147           Arab World  2004    12658.060443                 NaN

# %%
df_2009 = gdp_and_internet_use[gdp_and_internet_use["Year"].isin([2009])]

# %%
df_2009.head(10)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 9            Afghanistan  2009     1502.354073                3.55
# 26               Albania  2009     9525.377979               41.20
# 55               Algeria  2009    12697.690780               11.23
# 84                Angola  2009     6292.534856                6.00
# 113  Antigua and Barbuda  2009    22568.626530               42.00
# 142           Arab World  2009    14088.061299                 NaN
# 171            Argentina  2009    17302.654149               34.00
# 200              Armenia  2009     6534.077152               15.30
# 228                Aruba  2009    35830.497958               58.00
# 257            Australia  2009    41326.391930               74.25

# %%
df_2014 = gdp_and_internet_use[gdp_and_internet_use["Year"].isin([2014])]

# %%
df_2014.head(10)
# Out:
#                  Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4            Afghanistan  2014     1795.735834                6.39
# 21               Albania  2014    10700.993216               60.10
# 50               Algeria  2014    13557.769757               18.09
# 79                Angola  2014     6813.052106               21.26
# 108  Antigua and Barbuda  2014    20440.540555               64.00
# 137           Arab World  2014    15286.726815                 NaN
# 166            Argentina  2014    18935.002497               64.70
# 195              Armenia  2014     7954.195331               46.30
# 223                Aruba  2014    36172.933355               83.78
# 252            Australia  2014    43651.103133               84.56

# %% [markdown]
# Question 18 - Which country had the highest percentage of internet users in 2014? What was the percentage?
# Iceland, 98.16%

# %%
df_2014.sort_values(by='Internet_Users_Pct', ascending=False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2581              Iceland  2014    42774.888849               98.16
# 6772              Bermuda  2014             NaN               96.80
# 4530               Norway  2014    63328.259526               96.30
# 1404              Denmark  2014    45057.083449               95.99
# 6732              Andorra  2014             NaN               95.90
# ...                   ...   ...             ...                 ...
# 6245               Tuvalu  2014     3141.056160                 NaN
# 6418  Upper middle income  2014    14770.977043                 NaN
# 6563              Vietnam  2014     5312.492183                 NaN
# 6592   West Bank and Gaza  2014     4445.307470                 NaN
# 6617                World  2014    14514.392218                 NaN
#
# [278 rows x 4 columns]

# %% [markdown]
# Question 19 - Which country had the lowest percentage of internet users in 2014? What was the percentage?
# Dem.People's Rep. of Korea, 0.00%

# %%
df_2014.sort_values(by='Internet_Users_Pct', ascending=True)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6940  Dem. People's Rep. of Korea  2014             NaN                0.00
# 6999                      Eritrea  2014             NaN                0.99
# 6044                  Timor-Leste  2014     6466.737732                1.14
# 794                       Burundi  2014      768.469837                1.38
# 7521                      Somalia  2014             NaN                1.63
# ...                           ...   ...             ...                 ...
# 6245                       Tuvalu  2014     3141.056160                 NaN
# 6418          Upper middle income  2014    14770.977043                 NaN
# 6563                      Vietnam  2014     5312.492183                 NaN
# 6592           West Bank and Gaza  2014     4445.307470                 NaN
# 6617                        World  2014    14514.392218                 NaN
#
# [278 rows x 4 columns]

# %%
print(gdp_and_internet_use_subset)
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4               Afghanistan  2014     1795.735834            6.390000
# 9               Afghanistan  2009     1502.354073            3.550000
# 14              Afghanistan  2004     1025.208245            0.105809
# 21                  Albania  2014    10700.993216           60.100000
# 26                  Albania  2009     9525.377979           41.200000
# ...                     ...   ...             ...                 ...
# 7668               Viet Nam  2009             NaN           26.550000
# 7673               Viet Nam  2004             NaN            7.642409
# 7683  Virgin Islands (U.S.)  2014             NaN           50.070000
# 7688  Virgin Islands (U.S.)  2009             NaN           27.396510
# 7693  Virgin Islands (U.S.)  2004             NaN           27.377009
#
# [835 rows x 4 columns]

# %%
gdp_and_internet_use_subset.head()
# Out:
#         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 4   Afghanistan  2014     1795.735834            6.390000
# 9   Afghanistan  2009     1502.354073            3.550000
# 14  Afghanistan  2004     1025.208245            0.105809
# 21      Albania  2014    10700.993216           60.100000
# 26      Albania  2009     9525.377979           41.200000

# %%
gdp_and_internet_use_subset = gdp_and_internet_use_subset.reset_index(drop=True)
gdp_and_internet_use_subset.head()
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Dem. People's Rep. of Korea  2004             NaN            0.000000
# 1  Dem. People's Rep. of Korea  2014             NaN            0.000000
# 2  Dem. People's Rep. of Korea  2009             NaN            0.000000
# 3                      Myanmar  2004     1999.710075            0.024337
# 4                      Liberia  2004      916.487110            0.031011

# %% [markdown]
# Question 20 - Repeat for 2004 and 2009.
# 2004 - Dem. People's Rep. of Korea, 0.000000 %
# 2009 - Dem. People's Rep. of Korea, 0.000000 %

# %%
df_2009.sort_values(by='Internet_Users_Pct', ascending=True)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6944  Dem. People's Rep. of Korea  2009             NaN            0.000000
# 6049                  Timor-Leste  2009     9275.529371            0.185252
# 4233                      Myanmar  2009     3387.818242            0.220000
# 5292                 Sierra Leone  2009     1172.862734            0.260000
# 886                      Cambodia  2009     2417.293669            0.530000
# ...                           ...   ...             ...                 ...
# 6020                   The Gambia  2009     2467.890291                 NaN
# 6423          Upper middle income  2009    11631.478894                 NaN
# 6568                      Vietnam  2009     4207.756178                 NaN
# 6597           West Bank and Gaza  2009     3816.165070                 NaN
# 6622                        World  2009    12726.100963                 NaN
#
# [279 rows x 4 columns]

# %%
df_2004.sort_values(by='Internet_Users_Pct', ascending=True)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6949  Dem. People's Rep. of Korea  2004             NaN            0.000000
# 4238                      Myanmar  2004     1999.710075            0.024337
# 3470                      Liberia  2004      916.487110            0.031011
# 5910                   Tajikistan  2004     1644.455641            0.077480
# 14                    Afghanistan  2004     1025.208245            0.105809
# ...                           ...   ...             ...                 ...
# 6255                       Tuvalu  2004     3037.434007                 NaN
# 6428          Upper middle income  2004     8799.715484                 NaN
# 6573                      Vietnam  2004     3214.185135                 NaN
# 6602           West Bank and Gaza  2004     3324.834407                 NaN
# 6627                        World  2004    11351.109436                 NaN
#
# [278 rows x 4 columns]

# %% [markdown]
# Question 21 - Which country had the highest gdp per capita in 2014? What was the gdp per capita?
# Macao SAR, China - 130439.106674

# %%
df_2014.sort_values(by='GDP_Per_Capita', ascending=False)
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3639       Macao SAR, China  2014   130439.106674                 NaN
# 5003                  Qatar  2014   116693.507701               91.49
# 3610             Luxembourg  2014    92349.186429               94.67
# 5316              Singapore  2014    81965.361071               82.00
# 707                  Brunei  2014    76448.593329                 NaN
# ...                     ...   ...             ...                 ...
# 7541              Swaziland  2014             NaN               27.10
# 7562                  Syria  2014             NaN               28.09
# 7605     T.F.Y.R. Macedonia  2014             NaN               68.06
# 7663               Viet Nam  2014             NaN               48.31
# 7683  Virgin Islands (U.S.)  2014             NaN               50.07
#
# [278 rows x 4 columns]

# %% [markdown]
# Question 22 - Which country had the lowest gdp per capita in 2014? What was the gdp per capita?
# Central African Republic	2014	672.681648

# %%
df_2014.sort_values(by='GDP_Per_Capita', ascending=True)
# Out:
#                        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1014  Central African Republic  2014      672.681648                 NaN
# 794                    Burundi  2014      768.469837                1.38
# 1375           Dem. Rep. Congo  2014      784.872656                 NaN
# 4414                     Niger  2014      900.136918                1.95
# 3697                    Malawi  2014     1142.530804                5.83
# ...                        ...   ...             ...                 ...
# 7541                 Swaziland  2014             NaN               27.10
# 7562                     Syria  2014             NaN               28.09
# 7605        T.F.Y.R. Macedonia  2014             NaN               68.06
# 7663                  Viet Nam  2014             NaN               48.31
# 7683     Virgin Islands (U.S.)  2014             NaN               50.07
#
# [278 rows x 4 columns]

# %% [markdown]
# Question 23 - Create some scatterplots
# a. 2004 Percent Using the Internet vs GDP Per Capita
# b. 2009 Percent Using the Internet vs GDP Per Capita
# c. 2014 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(df_2004.Internet_Users_Pct, df_2004.GDP_Per_Capita)
plt.xlabel("Internet Users PCT")
plt.ylabel("GDP Per Capita")
plt.show()

# %%
plt.scatter(df_2009.Internet_Users_Pct, df_2009.GDP_Per_Capita)
plt.xlabel("Internet Users PCT")
plt.ylabel("GDP Per Capita")
plt.show()

# %%
plt.scatter(df_2014.Internet_Users_Pct, df_2014.GDP_Per_Capita)
plt.xlabel("Internet Users PCT")
plt.ylabel("GDP Per Capita")
plt.show()

# %% [markdown]
# Question 24 - Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.

# %% [markdown]
# 2004 vs 2009 there was not really noticeable difference, except perhaps 2009 had a lower gdp per capita overall. 2014 shows an increase in the percentage of internet users as the gdp per capita increases, and had a higher gdp per capita overall.

# %% [markdown]
# Question 25 - Look at the distribution of gdp per capita values for 2014. Is it unimodal? It appears that in 2014 there was a peak for gcp per capita, with a higher cluster of internet users during this peak, so yes it appears to be unimodal.

# %% [markdown]
# Question 26 - Look at the distribution of Internet Use for 2014. Is it unimodal?

# %% [markdown]
# Question 27 - What are the top 5 countries in terms of internet use in 2014?
#
# Iceland, Bermuda, Norway, Denmark, Andorra

# %%
df_2014.sort_values(by='Internet_Users_Pct', ascending=False)
# Out:
#                   Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2581              Iceland  2014    42774.888849               98.16
# 6772              Bermuda  2014             NaN               96.80
# 4530               Norway  2014    63328.259526               96.30
# 1404              Denmark  2014    45057.083449               95.99
# 6732              Andorra  2014             NaN               95.90
# ...                   ...   ...             ...                 ...
# 6245               Tuvalu  2014     3141.056160                 NaN
# 6418  Upper middle income  2014    14770.977043                 NaN
# 6563              Vietnam  2014     5312.492183                 NaN
# 6592   West Bank and Gaza  2014     4445.307470                 NaN
# 6617                World  2014    14514.392218                 NaN
#
# [278 rows x 4 columns]

# %% [markdown]
# Question 28 - Create a data frame called top_5_internet from the combined data frame that has all three years for these 5 countries. You should have 15 rows. Check that this is true.

# %%
top_5_internet = gdp_and_internet_use_subset[gdp_and_internet_use_subset["Country"].isin(['Iceland','Bermuda','Norway','Denmark','Andorra'])]
top_5_internet.head(20)
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 57   Bermuda  2009    57151.919132           83.250000
# 58   Bermuda  2004    55452.638880           60.990867
# 149  Denmark  2014    45057.083449           95.990000
# 150  Denmark  2009    43382.615688           86.840000
# 151  Denmark  2004    43670.446201           80.930000
# 271  Iceland  2014    42774.888849           98.160000
# 272  Iceland  2009    41505.084834           93.000000
# 273  Iceland  2004    38893.378798           83.880000
# 480   Norway  2014    63328.259526           96.300000
# 481   Norway  2009    62617.153609           92.080000
# 482   Norway  2004    61612.275634           77.690000
# 719  Andorra  2014             NaN           95.900000
# 720  Andorra  2009             NaN           78.530000
# 721  Andorra  2004             NaN           26.837954
# 725  Bermuda  2014             NaN           96.800000

# %% [markdown]
# Question 29 - Create a seaborn FacetGrid to show the internet usage trend over time for these 5 countries (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014? Is there a plotting issue with Bermuda? Can you fix it?
# Andorra has the greatest growth in % of Internet users from 2004 to 2014

# %%
##graph = sns.FacetGrid(top_5_internet, col ='Year', row='Country',hue='Country')
s = [10, 20, 40, 80]
graph = sns.FacetGrid(top_5_internet, col ='Year', hue='Country')
graph.map(plt.scatter, "Country", "Internet_Users_Pct",alpha = 1) 
fig = plt.gcf()
# Change plot size
fig.set_size_inches(20,8)

plt.show()

# %% [markdown]
# Question 30 - Repeat the steps above to look at the trend for the 5 countries with the lowest 2014 internet usage. Which country has consistently had the least internet use? - Dem. People's Republic of Korea

# %%
gdp_and_internet_use_subset.head(50)
#gdp_and_internet_use_subset.sort_values(by='Internet_Users_Pct', ascending=True)
# Out:
#                                Country  Year  GDP_Per_Capita  \
# 0          Dem. People's Rep. of Korea  2004             NaN
# 1          Dem. People's Rep. of Korea  2014             NaN
# 2          Dem. People's Rep. of Korea  2009             NaN
# 3                              Myanmar  2004     1999.710075
# 4                              Liberia  2004      916.487110
# 5                           Tajikistan  2004     1644.455641
# 6                          Afghanistan  2004     1025.208245
# 7                             Ethiopia  2004      676.917430
# 8                          Timor-Leste  2009     9275.529371
# 9                                Niger  2004      757.751262
# 10  Congo (Democratic Republic of the)  2004             NaN
# 11                          Bangladesh  2004     1896.763311
# 12                        Sierra Leone  2004     1057.693494
# 13                             Myanmar  2009     3387.818242
# 14                Central African Rep.  2004             NaN
# 15                        Sierra Leone  2009     1172.862734
# 16                            Cambodia  2004     1765.999799
# 17                              Malawi  2004      862.392437
# 18                             Burundi  2004      708.833720
# 19                                Chad  2004     1580.648456
# 20                          Lao P.D.R.  2004             NaN
# 21                        Burkina Faso  2004     1200.417062
# 22                              Rwanda  2004      988.117185
# 23                                Mali  2004     1710.107750
# 24                               Nepal  2004     1641.855723
# 25                              Angola  2004     4604.657044
# 26                          Mauritania  2004     2918.423476
# 27                              Guinea  2004     1583.864869
# 28                          Madagascar  2004     1595.654780
# 29                            Cambodia  2009     2417.293669
# 30                             Eritrea  2009     1950.533339
# 31                            Ethiopia  2009      981.718208
# 32  Congo (Democratic Republic of the)  2009             NaN
# 33                     Solomon Islands  2004     1633.531709
# 34                          Mozambique  2004      796.663666
# 35                              Uganda  2004     1223.739302
# 36                        Turkmenistan  2004     5808.659690
# 37                               Niger  2009      778.982257
# 38                            Djibouti  2004             NaN
# 39                               Sudan  2004     2631.297686
# 40                   Equatorial Guinea  2004    28384.466729
# 41                       Cote d'Ivoire  2004             NaN
# 42                            Tanzania  2004     1827.065912
# 43                               Yemen  2004     4145.345441
# 44                                Iraq  2004    10711.682945
# 45                             Burundi  2009      721.063140
# 46                              Guinea  2009     1626.288463
# 47                            Cameroon  2004     2799.099397
# 48                             Eritrea  2014             NaN
# 49                             Somalia  2004             NaN
#
#     Internet_Users_Pct
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             0.024337
# 4             0.031011
# 5             0.077480
# 6             0.105809
# 7             0.155335
# 8             0.185252
# 9             0.189934
# 10            0.196208
# 11            0.199036
# 12            0.203008
# 13            0.220000
# 14            0.223401
# 15            0.260000
# 16            0.300437
# 17            0.347505
# 18            0.349060
# 19            0.360920
# 20            0.361434
# 21            0.400295
# 22            0.430854
# 23            0.432820
# 24            0.449844
# 25            0.464815
# 26            0.481470
# 27            0.508819
# 28            0.525354
# 29            0.530000
# 30            0.540000
# 31            0.540000
# 32            0.560000
# 33            0.649673
# 34            0.679448
# 35            0.719971
# 36            0.754054
# 37            0.760000
# 38            0.781317
# 39            0.791562
# 40            0.843930
# 41            0.849282
# 42            0.877575
# 43            0.881223
# 44            0.900000
# 45            0.900000
# 46            0.940000
# 47            0.976075
# 48            0.990000
# 49            1.053455

# %%
bottom_5_internet = gdp_and_internet_use_subset[gdp_and_internet_use_subset["Country"].isin(["Dem. People's Rep. of Korea","Myanmar","Liberia","Tajikistan","Afghanistan"])]
print(bottom_5_internet)
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0    Dem. People's Rep. of Korea  2004             NaN            0.000000
# 1    Dem. People's Rep. of Korea  2014             NaN            0.000000
# 2    Dem. People's Rep. of Korea  2009             NaN            0.000000
# 3                        Myanmar  2004     1999.710075            0.024337
# 4                        Liberia  2004      916.487110            0.031011
# 5                     Tajikistan  2004     1644.455641            0.077480
# 6                    Afghanistan  2004     1025.208245            0.105809
# 13                       Myanmar  2009     3387.818242            0.220000
# 77                       Liberia  2009     1076.105620            2.000000
# 79                       Myanmar  2014     4737.459861            2.100000
# 112                  Afghanistan  2009     1502.354073            3.550000
# 140                      Liberia  2014     1257.625441            5.410000
# 154                  Afghanistan  2014     1795.735834            6.390000
# 204                   Tajikistan  2009     2051.726711           10.070000
# 256                   Tajikistan  2014     2580.247560           17.490000

# %%
s = [10, 20, 40, 80]
graph = sns.FacetGrid(bottom_5_internet, col ='Year', hue='Country')
graph.map(plt.scatter, "Country", "Internet_Users_Pct",alpha = 1) 
fig = plt.gcf()
# Change plot size
fig.set_size_inches(20,8)

plt.show()
